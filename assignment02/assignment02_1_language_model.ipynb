# %%
import os

# %%
import pandas as pd

# %%
import re

# %%
csvfile = "C:\\Users\\fangsj\\Desktop\\NLPcourse-2019.3\\pytest\\git-fessigy-AI-FOR-NLP\\AI-FOR-NLP\\assignment02\\sqlResult_1558435.csv"

# %%
dataframe = pd.read_csv(csvfile,encoding = "gb18030")

# %%
def token(string):
    return " ".join(re.findall('[\w|\d]+',string))

# %%
string = "此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n至于电池缩水，可能与刘作虎所说，一加手机5要做市面最轻薄大屏旗舰的设定有关。\r\n按照目前掌握的资料，一加手机5拥有5.5寸1080P三星AMOLED显示屏、6G/8GB RAM，64GB/128GB ROM，双1600万摄像头，备货量“惊喜”。\r\n根据京东泄露的信息，一加5起售价是xx99元，应该是在2799/2899/2999中的某个。\r\n'"

# %%
re.findall('[\w|\d]+',string)
# Out:
# ['此前的一加3T搭载的是3400mAh电池',
#  'DashCharge快充规格为5V',
#  '4A',
#  '至于电池缩水',
#  '可能与刘作虎所说',
#  '一加手机5要做市面最轻薄大屏旗舰的设定有关',
#  '按照目前掌握的资料',
#  '一加手机5拥有5',
#  '5寸1080P三星AMOLED显示屏',
#  '6G',
#  '8GB',
#  'RAM',
#  '64GB',
#  '128GB',
#  'ROM',
#  '双1600万摄像头',
#  '备货量',
#  '惊喜',
#  '根据京东泄露的信息',
#  '一加5起售价是xx99元',
#  '应该是在2799',
#  '2899',
#  '2999中的某个']

# %%
origintext = dataframe['content'].tolist()

# %%
all_articles = [token(str(s)) for s  in origintext]

# %%
text = ""

for a in all_articles:
    text += a

# %%
from functools import reduce

# %%
txt_from_reduce = reduce(lambda a1, a2: a1 + a2, text[:10])

# %%
txt_from_reduce
# Out:
# '此外 自本周 6月1'

# %%
TEXT = text

# %%
import jieba

# %%
def cut(string):
    return list(jieba.cut(string))

# %%
cut("这是一个测试")
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\fangsj\AppData\Local\Temp\jieba.cache
# Loading model cost 1.558 seconds.
# Prefix dict has been built succesfully.
# ['这是', '一个', '测试']

# %%
ALL_TOKENS = cut(TEXT)

# %%
ALL_TOKENS
# Out:
# ['此外',
#  ' ',
#  '自',
#  '本周',
#  ' ',
#  '6',
#  '月',
#  '12',
#  '日',
#  ' ',
#  '起',
#  ' ',
#  '除',
#  '小米',
#  '手机',
#  '6',
#  '等',
#  '15',
#  '款',
#  '机型',
#  '外',
#  ' ',
#  '其余',
#  '机型',
#  '已',
#  '暂停',
#  '更新',
#  '发布',
#  ' ',
#  '含',
#  '开发',
#  '版',
#  ' ',
#  '体验版',
#  '内测',
#  ' ',
#  '稳定版',
#  '暂不受',
#  '影响',
#  ' ',
#  '以',
#  '确保',
#  '工程师',
#  '可以',
#  '集中',
#  '全部',
#  '精力',
#  '进行',
#  '系统优化',
#  '工作',
#  ' ',
#  '有人',
#  '猜测',
#  '这',
#  '也',
#  '是',
#  '将',
#  '精力',
#  '主要',
#  '用到',
#  'MIUI',
#  ' ',
#  '9',
#  '的',
#  '研发',
#  '之中',
#  ' ',
#  'MIUI',
#  ' ',
#  '8',
#  '去年',
#  '5',
#  '月',
#  '发布',
#  ' ',
#  '距今已有',
#  '一年',
#  '有余',
#  ' ',
#  '也',
#  '是',
#  '时候',
#  '更新换代',
#  '了',
#  ' ',
#  '当然',
#  ' ',
#  '关于',
#  'MIUI',
#  ' ',
#  '9',
#  '的',
#  '确切',
#  '信息',
#  ' ',
#  '我们',
#  '还是',
#  '等待',
#  '官方消息',
#  '骁龙',
#  '835',
#  '作为',
#  '唯一',
#  '通过',
#  'Windows',
#  ' ',
#  '10',
#  '桌面',
#  '平台',
#  '认证',
#  '的',
#  'ARM',
#  '处理器',
# ...

# %%
len(ALL_TOKENS)
# Out:
# 21906852

# %%
valid_tokens = [t for t in ALL_TOKENS if t.strip() and t!="n"]

# %%
valid_tokens
# Out:
# ['此外',
#  '自',
#  '本周',
#  '6',
#  '月',
#  '12',
#  '日',
#  '起',
#  '除',
#  '小米',
#  '手机',
#  '6',
#  '等',
#  '15',
#  '款',
#  '机型',
#  '外',
#  '其余',
#  '机型',
#  '已',
#  '暂停',
#  '更新',
#  '发布',
#  '含',
#  '开发',
#  '版',
#  '体验版',
#  '内测',
#  '稳定版',
#  '暂不受',
#  '影响',
#  '以',
#  '确保',
#  '工程师',
#  '可以',
#  '集中',
#  '全部',
#  '精力',
#  '进行',
#  '系统优化',
#  '工作',
#  '有人',
#  '猜测',
#  '这',
#  '也',
#  '是',
#  '将',
#  '精力',
#  '主要',
#  '用到',
#  'MIUI',
#  '9',
#  '的',
#  '研发',
#  '之中',
#  'MIUI',
#  '8',
#  '去年',
#  '5',
#  '月',
#  '发布',
#  '距今已有',
#  '一年',
#  '有余',
#  '也',
#  '是',
#  '时候',
#  '更新换代',
#  '了',
#  '当然',
#  '关于',
#  'MIUI',
#  '9',
#  '的',
#  '确切',
#  '信息',
#  '我们',
#  '还是',
#  '等待',
#  '官方消息',
#  '骁龙',
#  '835',
#  '作为',
#  '唯一',
#  '通过',
#  'Windows',
#  '10',
#  '桌面',
#  '平台',
#  '认证',
#  '的',
#  'ARM',
#  '处理器',
#  '高通',
#  '强调',
#  '不会',
#  '因为',
#  '只',
#  '考虑',
#  '性能',
#  '而',
#  '去',
#  '屏蔽掉',
#  '小',
#  '核心',
#  '相反',
#  '他们',
#  '正',
#  '联手',
#  '微软',
#  '找到',
# ...

# %%
len(valid_tokens)
# Out:
# 17221785

# %%
#get the frequency of words

# %%
from collections import Counter

# %%
words_count = Counter(valid_tokens)

# %%
words_count.most_common(10)
# Out:
# [('的', 703820),
#  ('在', 264633),
#  ('月', 189525),
#  ('日', 169920),
#  ('新华社', 142462),
#  ('和', 134220),
#  ('年', 123531),
#  ('了', 121904),
#  ('是', 100288),
#  ('１', 88187)]

# %%
frequences = [f for w,f in words_count.most_common(100)]

# %%
x = [i for i in range(len(frequences[:100]))]

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
plt.plot(x, np.log(frequences))

# %%
frequency_all = [f for w,f in words_count.most_common()]

# %%
frequency_all
# Out:
# [703820,
#  264633,
#  189525,
#  169920,
#  142462,
#  134220,
#  123531,
#  121904,
#  100288,
#  88187,
#  84945,
#  83263,
#  78950,
#  77935,
#  71180,
#  70521,
#  64720,
#  62276,
#  62082,
#  61657,
#  60640,
#  58383,
#  58317,
#  58103,
#  52271,
#  50582,
#  48836,
#  47399,
#  46556,
#  40857,
#  40081,
#  38168,
#  37648,
#  37118,
#  36906,
#  36059,
#  35921,
#  35082,
#  34659,
#  33954,
#  33893,
#  32235,
#  30575,
#  30575,
#  30451,
#  29693,
#  28679,
#  28420,
#  28042,
#  27189,
#  26691,
#  26575,
#  26456,
#  26386,
#  26155,
#  25986,
#  25510,
#  25391,
#  25288,
#  25252,
#  24945,
#  23925,
#  23362,
#  23334,
#  23044,
#  22761,
#  22556,
#  22208,
#  22175,
#  21937,
#  21920,
#  21786,
#  21713,
#  21589,
#  21406,
#  21076,
#  21046,
#  21004,
#  20722,
#  20701,
#  20327,
#  19987,
#  19982,
#  19209,
#  19029,
#  18995,
#  18905,
#  18882,
#  18757,
#  18678,
#  18416,
#  18167,
#  18152,
#  18128,
#  17644,
#  17404,
#  17350,
#  17310,
#  17309,
# ...

# %%
frequency_sum = sum(frequency_all)

# %%
frequency_sum
# Out:
# 17221785

# %%
def get_prob(word):
    esp = 1/frequency_sum
    if word in words_count:
        return words_count[word]/frequency_sum
    else:
        return esp

# %%
import re

# %%
get_prob("我们")
# Out:
# 0.0011602746172943166

# %%
from functools import reduce

# %%
def product(numbers):
    return reduce(lambda n1, n2 : n1 * n2, numbers)

# %%
product([1,2,3,4,10])
# Out:
# 240

# %%
def language_model_one_gram(string):
    words = cut(string)
    return product([get_prob(i) for i in words])

# %%
language_model_one_gram("广交会下个月举办")
# Out:
# 1.4093284706718309e-14

# %%
language_model_one_gram('长征火箭下周发射')
# Out:
# 1.4511549339176565e-18

# %%
sentences = """
这是一个比较正常的句子
这个一个比较罕见的句子
小明毕业于清华大学
小明毕业于秦华大学
""".split()

# %%
sentences
# Out:
# ['这是一个比较正常的句子', '这个一个比较罕见的句子', '小明毕业于清华大学', '小明毕业于秦华大学']

# %%
for s in sentences:
    print(language_model_one_gram(s))
# Out:
# 7.429984647015532e-22
# 1.7566783516469408e-22
# 3.039960976514903e-18
# 5.813337476916057e-24

# %%
need_compared = [
    "今天晚上请你吃大餐，我们一起吃日料 明天晚上请你吃大餐，我们一起吃苹果",
    "真事一只好看的小猫 真是一只好看的小猫",
    "我去吃火锅，今晚 今晚我去吃火锅"
]

# %%
for s in need_compared:
    s1,s2 = s.split()
    p1,p2 = language_model_one_gram(s1),language_model_one_gram(s2)
    
    better = s1 if p1 > p2 else s2
    
    print("{} is more possible,".format(better))
    print("-"*4 + "{} with probability {}".format(s1,p1))
    print("-"*4 + "{} with probability {}".format(s2,p2))
# Out:
# 明天晚上请你吃大餐，我们一起吃苹果 is more possible,
# ----今天晚上请你吃大餐，我们一起吃日料 with probability 6.279484454158278e-50
# ----明天晚上请你吃大餐，我们一起吃苹果 with probability 5.1533768284792506e-48
# 真是一只好看的小猫 is more possible,
# ----真事一只好看的小猫 with probability 2.873219522813593e-25
# ----真是一只好看的小猫 with probability 1.0935351206452033e-21
# 今晚我去吃火锅 is more possible,
# ----我去吃火锅，今晚 with probability 6.876097222574346e-26
# ----今晚我去吃火锅 with probability 1.1841866800627252e-18

# %% [markdown]
# 2-gram

# %% [markdown]
# $$P(w_2|w_1)=\frac{P(w_1·w_2)}{P(w_1)}$$

# %%
valid_tokens_str = [str(t) for t in valid_tokens]

# %%
all_2_grams_words = [''.join(valid_tokens_str[i:i+2]) for i in range(len(valid_tokens_str[:-2]))]

# %%
_2_gram_counter = Counter(all_2_grams_words)

# %%
_2_gram_sum = len(all_2_grams_words)
#个人觉得这里不应该是len(_2_gram_counter)，而应该是sum(_2_gram_counter)/2

# %%
def get_combination_prob(w1,w2):
    if w1 + w2 in _2_gram_counter:return _2_gram_counter[w1+w2]/_2_gram_sum
    else:return 1/_2_gram_sum

# %%
get_combination_prob('去', '北京')
# Out:
# 1.8000459069772276e-06

# %%
get_combination_prob('波音', '飞机')
# Out:
# 8.129239579897157e-07

# %%
def get_prob_2_gram(w1,w2):
    return get_combination_prob(w1,w2)/get_prob(w1)

# %%
get_prob_2_gram('去', '沈阳')
# Out:
# 0.0006857770649650213

# %%
type(get_prob_2_gram('去', '北京'))
# Out:
# float

# %%
type(get_prob("北京"))
# Out:
# float

# %%
def language_model_of_2_gram(sentence):
    sentence_probability = 1
    
    words = cut(sentence)
    
    for i ,w in enumerate(words):
        if i == 0:
            prob = get_prob(w)
        else:
            previous = words[i-1]
            prob = get_prob_2_gram(previous, w)
        sentence_probability *= prob
    return sentence_probability

# %%
language_model_of_2_gram('小明今天抽奖抽到一台苹果手机')
# Out:
# 4.5133725473313174e-18

# %%
language_model_of_2_gram('小明今天抽奖抽到一台波音飞机')
# Out:
# 3.9724842499924055e-18

# %%
need_compared = [
    "今天晚上请你吃大餐，我们一起吃日料 明天晚上请你吃大餐，我们一起吃苹果",
    "真事一只好看的小猫 真是一只好看的小猫",
    "今晚我去吃火锅 今晚火锅去吃我",
    "洋葱奶昔来一杯 养乐多绿来一杯"
]

# %%
for s in need_compared:
    s1,s2 = s.split()
    p1,p2 =language_model_of_2_gram(s1),language_model_of_2_gram(s2)
    
    better = s1 if p1>p2 else s2
    
    print('{} is more possible'.format(better))
    print('-'*4 + '{} with probility {}'.format(s1,p1))
    print('-'*4 + '{} with probility {}'.format(s2,p2))
# Out:
# 今天晚上请你吃大餐，我们一起吃日料 is more possible
# ----今天晚上请你吃大餐，我们一起吃日料 with probility 6.895905640955031e-28
# ----明天晚上请你吃大餐，我们一起吃苹果 with probility 5.516724512764024e-28
# 真是一只好看的小猫 is more possible
# ----真事一只好看的小猫 with probility 1.6570998748154123e-19
# ----真是一只好看的小猫 with probility 3.4765951336188093e-16
# 今晚我去吃火锅 is more possible
# ----今晚我去吃火锅 with probility 6.82225584071837e-14
# ----今晚火锅去吃我 with probility 9.986004768787415e-16
# 养乐多绿来一杯 is more possible
# ----洋葱奶昔来一杯 with probility 1.0579577386518395e-12
# ----养乐多绿来一杯 with probility 5.806600374258542e-08
